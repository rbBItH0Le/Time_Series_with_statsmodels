# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from statsmodels.tsa.stattools import pacf_ols,pacf_yw,acf,acovf

# %%
import statsmodels.api as sm

# %%
df=pd.read_csv('airline_passengers.csv',index_col='Month',parse_dates=True)

# %%
df.index.freq='MS'

# %%
df1=pd.read_csv('DailyTotalFemaleBirths.csv',index_col='Date',parse_dates=True)

# %%
df1.index.freq='D'

# %%
df1.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(df['Thousands of Passengers'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
lag_plot(df1['Births'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
plot_acf(df['Thousands of Passengers'],lags=44)

# %%
plot_acf(df1['Births'],lags=44)

# %%
plot_pacf(df1['Births'],lags=40)
